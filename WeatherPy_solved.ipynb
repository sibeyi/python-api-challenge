# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress
from datetime import datetime

# Impor the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 601

# %%
#Set units for search
units = "metric"

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# Set the API base URL
url = "http://api.openweathermap.org/data/2.5/weather?"

# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = f"{url}appid={weather_api_key}&q={city}&units={units}"
    
    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        weather_response = requests.get(city_url)
        city_weather = weather_response.json()

        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_date = city_weather["dt"]

        # Append the City information into city_data list
        city_data.append({"City": city, 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
              
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | gaigeturi
# Processing Record 2 of Set 1 | margate
# Processing Record 3 of Set 1 | puerto natales
# Processing Record 4 of Set 1 | hayma'
# City not found. Skipping...
# Processing Record 5 of Set 1 | grytviken
# Processing Record 6 of Set 1 | port-aux-francais
# Processing Record 7 of Set 1 | port mathurin
# Processing Record 8 of Set 1 | harnai
# Processing Record 9 of Set 1 | waitangi
# Processing Record 10 of Set 1 | terra santa
# Processing Record 11 of Set 1 | afaahiti
# Processing Record 12 of Set 1 | north bondi
# Processing Record 13 of Set 1 | jining
# Processing Record 14 of Set 1 | hawaiian paradise park
# Processing Record 15 of Set 1 | hermanus
# Processing Record 16 of Set 1 | ribeira grande
# Processing Record 17 of Set 1 | happy valley-goose bay
# Processing Record 18 of Set 1 | fale old settlement
# Processing Record 19 of Set 1 | albany
# Processing Record 20 of Set 1 | tura
# Processing Record 21 of Set 1 | adamstown
# Processing Record 22 of Set 1 | taro
# Processing Record 23 of Set 1 | salzwedel
# Processing Record 24 of Set 1 | kayangel
# Processing Record 25 of Set 1 | badger
# Processing Record 26 of Set 1 | da lat
# Processing Record 27 of Set 1 | taiohae
# City not found. Skipping...
# Processing Record 28 of Set 1 | barcelos
# Processing Record 29 of Set 1 | bilibino
# Processing Record 30 of Set 1 | tiksi
# Processing Record 31 of Set 1 | stanley
# Processing Record 32 of Set 1 | west island
# Processing Record 33 of Set 1 | puerto baquerizo moreno
# Processing Record 34 of Set 1 | wailua homesteads
# Processing Record 35 of Set 1 | iqaluit
# Processing Record 36 of Set 1 | panji
# Processing Record 37 of Set 1 | lebu
# Processing Record 38 of Set 1 | hirara
# Processing Record 39 of Set 1 | cassia
# Processing Record 40 of Set 1 | luderitz
# Processing Record 41 of Set 1 | hobyo
# Processing Record 42 of Set 1 | xining
# Processing Record 43 of Set 1 | banda aceh
# Processing Record 44 of Set 1 | ouani
# Processing Record 45 of Set 1 | bahia de kino
# Processing Record 46 of Set 1 | tegueste
# Processing Record 47 of Set 1 | ancud
# Processing Record 48 of Set 1 | laojunmiao
# Processing Record 49 of Set 1 | teknaf
# Processing Record 50 of Set 1 | mount isa
# Processing Record 0 of Set 2 | talnakh
# Processing Record 1 of Set 2 | kangding
# Processing Record 2 of Set 2 | whittlesea
# Processing Record 3 of Set 2 | ozorkow
# Processing Record 4 of Set 2 | nova sintra
# Processing Record 5 of Set 2 | st. john's
# Processing Record 6 of Set 2 | blackmans bay
# Processing Record 7 of Set 2 | port elizabeth
# Processing Record 8 of Set 2 | nsunga
# Processing Record 9 of Set 2 | edinburgh of the seven seas
# Processing Record 10 of Set 2 | longyearbyen
# Processing Record 11 of Set 2 | enewetak
# Processing Record 12 of Set 2 | inhambane
# Processing Record 13 of Set 2 | bethel
# Processing Record 14 of Set 2 | karagay
# Processing Record 15 of Set 2 | massenya
# Processing Record 16 of Set 2 | petukhovo
# Processing Record 17 of Set 2 | leava
# Processing Record 18 of Set 2 | asubulaq
# Processing Record 19 of Set 2 | khorixas
# Processing Record 20 of Set 2 | thompson
# Processing Record 21 of Set 2 | fort bragg
# Processing Record 22 of Set 2 | makhambet
# Processing Record 23 of Set 2 | pangkalanbuun
# Processing Record 24 of Set 2 | ilulissat
# Processing Record 25 of Set 2 | prince rupert
# Processing Record 26 of Set 2 | usinsk
# Processing Record 27 of Set 2 | daru
# Processing Record 28 of Set 2 | pacific grove
# Processing Record 29 of Set 2 | uttar char fasson
# Processing Record 30 of Set 2 | la ronge
# Processing Record 31 of Set 2 | avarua
# Processing Record 32 of Set 2 | kishtwar
# Processing Record 33 of Set 2 | invercargill
# Processing Record 34 of Set 2 | berezovyy
# Processing Record 35 of Set 2 | tual
# Processing Record 36 of Set 2 | qaqortoq
# Processing Record 37 of Set 2 | holualoa
# Processing Record 38 of Set 2 | malango
# Processing Record 39 of Set 2 | hekimhan
# Processing Record 40 of Set 2 | karratha
# Processing Record 41 of Set 2 | kavaratti
# Processing Record 42 of Set 2 | yellowknife
# Processing Record 43 of Set 2 | champerico
# Processing Record 44 of Set 2 | puerto ayora
# Processing Record 45 of Set 2 | kidal
# Processing Record 46 of Set 2 | petropavlovsk-kamchatsky
# Processing Record 47 of Set 2 | gunnedah
# Processing Record 48 of Set 2 | praia da vitoria
# Processing Record 49 of Set 2 | mogocha
# Processing Record 0 of Set 3 | namibe
# Processing Record 1 of Set 3 | constantia
# Processing Record 2 of Set 3 | puerto san carlos
# City not found. Skipping...
# Processing Record 3 of Set 3 | ataq
# Processing Record 4 of Set 3 | mugumu
# Processing Record 5 of Set 3 | souillac
# Processing Record 6 of Set 3 | jamestown
# Processing Record 7 of Set 3 | amarpatan
# Processing Record 8 of Set 3 | college
# Processing Record 9 of Set 3 | iskateley
# Processing Record 10 of Set 3 | yagry
# City not found. Skipping...
# Processing Record 11 of Set 3 | guixi
# Processing Record 12 of Set 3 | uturoa
# Processing Record 13 of Set 3 | cabo san lucas
# Processing Record 14 of Set 3 | aykhal
# Processing Record 15 of Set 3 | saipan
# Processing Record 16 of Set 3 | al kharijah
# Processing Record 17 of Set 3 | presidencia de la plaza
# Processing Record 18 of Set 3 | ugoofaaru
# Processing Record 19 of Set 3 | nyandoma
# Processing Record 20 of Set 3 | bani walid
# Processing Record 21 of Set 3 | 'ohonua
# City not found. Skipping...
# Processing Record 22 of Set 3 | nizhnyaya poyma
# Processing Record 23 of Set 3 | punta arenas
# Processing Record 24 of Set 3 | kapa'a
# Processing Record 25 of Set 3 | lata
# Processing Record 26 of Set 3 | manicore
# Processing Record 27 of Set 3 | whitehorse
# Processing Record 28 of Set 3 | howrah
# Processing Record 29 of Set 3 | saudarkrokur
# Processing Record 30 of Set 3 | vadso
# Processing Record 31 of Set 3 | sao joao da barra
# Processing Record 32 of Set 3 | dompu
# Processing Record 33 of Set 3 | lazaro cardenas
# Processing Record 34 of Set 3 | papatowai
# Processing Record 35 of Set 3 | halle (saale)
# Processing Record 36 of Set 3 | tazacorte
# Processing Record 37 of Set 3 | amga
# Processing Record 38 of Set 3 | andergrove
# Processing Record 39 of Set 3 | merizo village
# Processing Record 40 of Set 3 | katima mulilo
# Processing Record 41 of Set 3 | murzuq
# Processing Record 42 of Set 3 | madera
# Processing Record 43 of Set 3 | san antonio de pale
# Processing Record 44 of Set 3 | severo-yeniseyskiy
# Processing Record 45 of Set 3 | walvis bay
# Processing Record 46 of Set 3 | north ward
# Processing Record 47 of Set 3 | isafjordur
# Processing Record 48 of Set 3 | kindu
# Processing Record 49 of Set 3 | mahina
# Processing Record 0 of Set 4 | kingston
# Processing Record 1 of Set 4 | villamontes
# Processing Record 2 of Set 4 | ghadamis
# Processing Record 3 of Set 4 | bashtanka
# Processing Record 4 of Set 4 | ushuaia
# Processing Record 5 of Set 4 | ta`u
# Processing Record 6 of Set 4 | joao pinheiro
# Processing Record 7 of Set 4 | hasaki
# Processing Record 8 of Set 4 | akureyri
# Processing Record 9 of Set 4 | vila velha
# Processing Record 10 of Set 4 | san pedro pochutla
# Processing Record 11 of Set 4 | megion
# Processing Record 12 of Set 4 | pursat
# Processing Record 13 of Set 4 | greymouth
# Processing Record 14 of Set 4 | rio preto da eva
# Processing Record 15 of Set 4 | neyshabur
# Processing Record 16 of Set 4 | atafu village
# Processing Record 17 of Set 4 | port lincoln
# Processing Record 18 of Set 4 | porto novo
# Processing Record 19 of Set 4 | al ghayzah
# Processing Record 20 of Set 4 | vuktyl
# Processing Record 21 of Set 4 | vigan
# Processing Record 22 of Set 4 | georgetown
# Processing Record 23 of Set 4 | colares
# Processing Record 24 of Set 4 | yatou
# Processing Record 25 of Set 4 | parambu
# Processing Record 26 of Set 4 | margaret river
# Processing Record 27 of Set 4 | hamilton
# Processing Record 28 of Set 4 | olonkinbyen
# Processing Record 29 of Set 4 | vorkuta
# Processing Record 30 of Set 4 | keflavik
# Processing Record 31 of Set 4 | mount gambier
# Processing Record 32 of Set 4 | ahau
# City not found. Skipping...
# Processing Record 33 of Set 4 | hithadhoo
# Processing Record 34 of Set 4 | aracataca
# Processing Record 35 of Set 4 | turbat
# Processing Record 36 of Set 4 | siwa oasis
# Processing Record 37 of Set 4 | lodwar
# Processing Record 38 of Set 4 | udachny
# Processing Record 39 of Set 4 | carnarvon
# Processing Record 40 of Set 4 | palu
# Processing Record 41 of Set 4 | tver
# Processing Record 42 of Set 4 | geraldton
# Processing Record 43 of Set 4 | bridgewater
# Processing Record 44 of Set 4 | nadym
# Processing Record 45 of Set 4 | port saint john's
# Processing Record 46 of Set 4 | port macquarie
# Processing Record 47 of Set 4 | lospalos
# Processing Record 48 of Set 4 | krasnoarmeysk
# Processing Record 49 of Set 4 | kandira
# Processing Record 0 of Set 5 | capayan
# Processing Record 1 of Set 5 | kununurra
# Processing Record 2 of Set 5 | dawei
# Processing Record 3 of Set 5 | queenstown
# Processing Record 4 of Set 5 | la passe
# Processing Record 5 of Set 5 | tazovsky
# Processing Record 6 of Set 5 | port lavaca
# Processing Record 7 of Set 5 | vilyuchinsk
# Processing Record 8 of Set 5 | klyuchi
# Processing Record 9 of Set 5 | l'aquila
# Processing Record 10 of Set 5 | sao vicente
# Processing Record 11 of Set 5 | barra de santo antonio
# Processing Record 12 of Set 5 | alaghsas
# Processing Record 13 of Set 5 | lompoc
# Processing Record 14 of Set 5 | thaon-les-vosges
# Processing Record 15 of Set 5 | raja
# Processing Record 16 of Set 5 | port hedland
# Processing Record 17 of Set 5 | dul'durga
# Processing Record 18 of Set 5 | argo
# Processing Record 19 of Set 5 | taroudant
# Processing Record 20 of Set 5 | alta
# Processing Record 21 of Set 5 | iron river
# Processing Record 22 of Set 5 | zhengzhou
# Processing Record 23 of Set 5 | utrik
# Processing Record 24 of Set 5 | metlili chaamba
# Processing Record 25 of Set 5 | nobeoka
# Processing Record 26 of Set 5 | nuku'alofa
# Processing Record 27 of Set 5 | akjoujt
# Processing Record 28 of Set 5 | ust-nera
# Processing Record 29 of Set 5 | isangel
# Processing Record 30 of Set 5 | shingu
# Processing Record 31 of Set 5 | sena madureira
# Processing Record 32 of Set 5 | vernon
# Processing Record 33 of Set 5 | vohipaho
# City not found. Skipping...
# Processing Record 34 of Set 5 | kuala terengganu
# Processing Record 35 of Set 5 | susuman
# Processing Record 36 of Set 5 | egilsstadir
# Processing Record 37 of Set 5 | nemuro
# Processing Record 38 of Set 5 | motueka
# Processing Record 39 of Set 5 | carauari
# Processing Record 40 of Set 5 | adam
# Processing Record 41 of Set 5 | lashio
# Processing Record 42 of Set 5 | kedougou
# Processing Record 43 of Set 5 | benjamin constant
# Processing Record 44 of Set 5 | neiafu
# Processing Record 45 of Set 5 | gongchangling
# Processing Record 46 of Set 5 | san nicolas
# Processing Record 47 of Set 5 | bandarbeyla
# Processing Record 48 of Set 5 | sona
# Processing Record 49 of Set 5 | whyalla stuart
# City not found. Skipping...
# Processing Record 0 of Set 6 | guerrero negro
# Processing Record 1 of Set 6 | dzhambeyty
# Processing Record 2 of Set 6 | baukau
# Processing Record 3 of Set 6 | bandon
# Processing Record 4 of Set 6 | port alfred
# Processing Record 5 of Set 6 | cannonvale
# Processing Record 6 of Set 6 | nar'yan-mar
# Processing Record 7 of Set 6 | nelson bay
# Processing Record 8 of Set 6 | bijie
# Processing Record 9 of Set 6 | deniliquin
# Processing Record 10 of Set 6 | kstovo
# Processing Record 11 of Set 6 | sommatino
# Processing Record 12 of Set 6 | savyntsi
# Processing Record 13 of Set 6 | upata
# Processing Record 14 of Set 6 | saldanha
# Processing Record 15 of Set 6 | castillos
# Processing Record 16 of Set 6 | amstetten
# Processing Record 17 of Set 6 | ytyk-kyuyel'
# City not found. Skipping...
# Processing Record 18 of Set 6 | ponta delgada
# Processing Record 19 of Set 6 | mae sai
# Processing Record 20 of Set 6 | aasiaat
# Processing Record 21 of Set 6 | okhotsk
# Processing Record 22 of Set 6 | fountain
# Processing Record 23 of Set 6 | patnongon
# Processing Record 24 of Set 6 | mineros
# Processing Record 25 of Set 6 | bredasdorp
# Processing Record 26 of Set 6 | bubaque
# Processing Record 27 of Set 6 | touros
# Processing Record 28 of Set 6 | port augusta
# Processing Record 29 of Set 6 | mulayjah
# Processing Record 30 of Set 6 | alofi
# Processing Record 31 of Set 6 | funadhoo
# Processing Record 32 of Set 6 | pagar alam
# Processing Record 33 of Set 6 | ghat
# Processing Record 34 of Set 6 | mirny
# Processing Record 35 of Set 6 | codrington
# Processing Record 36 of Set 6 | tezontepec
# Processing Record 37 of Set 6 | itoman
# Processing Record 38 of Set 6 | mandalgovi
# Processing Record 39 of Set 6 | dudinka
# Processing Record 40 of Set 6 | kas
# Processing Record 41 of Set 6 | katihar
# Processing Record 42 of Set 6 | buka
# Processing Record 43 of Set 6 | chonchi
# Processing Record 44 of Set 6 | sisimiut
# Processing Record 45 of Set 6 | borba
# Processing Record 46 of Set 6 | wanning
# Processing Record 47 of Set 6 | kuanda
# Processing Record 48 of Set 6 | devarkonda
# Processing Record 49 of Set 6 | imperial beach
# Processing Record 0 of Set 7 | ta'izz
# Processing Record 1 of Set 7 | keren
# Processing Record 2 of Set 7 | sittwe
# Processing Record 3 of Set 7 | stettler
# Processing Record 4 of Set 7 | alto barinas
# Processing Record 5 of Set 7 | polyarnyy
# Processing Record 6 of Set 7 | palangkaraya
# Processing Record 7 of Set 7 | arraial do cabo
# Processing Record 8 of Set 7 | tobelo
# Processing Record 9 of Set 7 | amungan
# Processing Record 10 of Set 7 | les anglais
# Processing Record 11 of Set 7 | forbes
# Processing Record 12 of Set 7 | nieuw amsterdam
# Processing Record 13 of Set 7 | island harbour
# Processing Record 14 of Set 7 | tomohon
# Processing Record 15 of Set 7 | xiongzhou
# Processing Record 16 of Set 7 | lan sak
# Processing Record 17 of Set 7 | la'ie
# Processing Record 18 of Set 7 | tranovaho
# City not found. Skipping...
# Processing Record 19 of Set 7 | fort mcmurray
# Processing Record 20 of Set 7 | ga-kgapane
# Processing Record 21 of Set 7 | nuuk
# Processing Record 22 of Set 7 | zhalantun
# Processing Record 23 of Set 7 | quellon
# Processing Record 24 of Set 7 | fisterra
# Processing Record 25 of Set 7 | selfoss
# Processing Record 26 of Set 7 | glace bay
# Processing Record 27 of Set 7 | broken hill
# Processing Record 28 of Set 7 | carahue
# Processing Record 29 of Set 7 | cangzhou
# Processing Record 30 of Set 7 | chernyshevskiy
# Processing Record 31 of Set 7 | lodja
# Processing Record 32 of Set 7 | acarau
# Processing Record 33 of Set 7 | lorengau
# Processing Record 34 of Set 7 | alice springs
# Processing Record 35 of Set 7 | crane
# Processing Record 36 of Set 7 | kodiak
# Processing Record 37 of Set 7 | christchurch
# Processing Record 38 of Set 7 | nouadhibou
# Processing Record 39 of Set 7 | lionel town
# Processing Record 40 of Set 7 | manadhoo
# Processing Record 41 of Set 7 | trairi
# Processing Record 42 of Set 7 | weno
# Processing Record 43 of Set 7 | anadyr
# Processing Record 44 of Set 7 | ferkessedougou
# Processing Record 45 of Set 7 | mildura
# Processing Record 46 of Set 7 | lillehammer
# Processing Record 47 of Set 7 | nogliki
# Processing Record 48 of Set 7 | taltal
# Processing Record 49 of Set 7 | minas de marcona
# Processing Record 0 of Set 8 | sandnessjoen
# Processing Record 1 of Set 8 | igarka
# Processing Record 2 of Set 8 | fortuna
# Processing Record 3 of Set 8 | altai
# Processing Record 4 of Set 8 | flying fish cove
# Processing Record 5 of Set 8 | tindouf
# Processing Record 6 of Set 8 | saynshand
# Processing Record 7 of Set 8 | beledweyne
# Processing Record 8 of Set 8 | sarangani
# Processing Record 9 of Set 8 | beloyarskiy
# Processing Record 10 of Set 8 | trebon
# Processing Record 11 of Set 8 | al jabin
# Processing Record 12 of Set 8 | dhidhdhoo
# Processing Record 13 of Set 8 | zelenogradsk
# Processing Record 14 of Set 8 | vorgashor
# Processing Record 15 of Set 8 | nago
# Processing Record 16 of Set 8 | remire-montjoly
# Processing Record 17 of Set 8 | kapuskasing
# Processing Record 18 of Set 8 | tommot
# Processing Record 19 of Set 8 | villa gesell
# Processing Record 20 of Set 8 | ourilandia do norte
# City not found. Skipping...
# Processing Record 21 of Set 8 | piti village
# Processing Record 22 of Set 8 | naze
# Processing Record 23 of Set 8 | tymovskoye
# Processing Record 24 of Set 8 | metu
# Processing Record 25 of Set 8 | mundri
# Processing Record 26 of Set 8 | tachilek
# City not found. Skipping...
# Processing Record 27 of Set 8 | lihue
# Processing Record 28 of Set 8 | colonia
# Processing Record 29 of Set 8 | sniatyn
# Processing Record 30 of Set 8 | ola
# Processing Record 31 of Set 8 | zakamensk
# Processing Record 32 of Set 8 | beyneu
# Processing Record 33 of Set 8 | abadeh
# Processing Record 34 of Set 8 | buala
# Processing Record 35 of Set 8 | cantilan
# Processing Record 36 of Set 8 | jackson
# Processing Record 37 of Set 8 | zangguy
# City not found. Skipping...
# Processing Record 38 of Set 8 | gereida
# Processing Record 39 of Set 8 | piacabucu
# Processing Record 40 of Set 8 | ulan bator
# Processing Record 41 of Set 8 | calama
# Processing Record 42 of Set 8 | pisco
# Processing Record 43 of Set 8 | taoudenni
# Processing Record 44 of Set 8 | ciudad bolivar
# Processing Record 45 of Set 8 | lhokseumawe
# Processing Record 46 of Set 8 | baiti
# Processing Record 47 of Set 8 | asipovichy
# Processing Record 48 of Set 8 | orapa
# Processing Record 49 of Set 8 | goundam
# Processing Record 0 of Set 9 | masjed soleyman
# Processing Record 1 of Set 9 | huarmey
# Processing Record 2 of Set 9 | acala
# Processing Record 3 of Set 9 | kirakira
# Processing Record 4 of Set 9 | kerema
# Processing Record 5 of Set 9 | rongelap
# Processing Record 6 of Set 9 | saint-philippe
# Processing Record 7 of Set 9 | san patricio
# Processing Record 8 of Set 9 | petawawa
# Processing Record 9 of Set 9 | sept-iles
# Processing Record 10 of Set 9 | kudahuvadhoo
# Processing Record 11 of Set 9 | ad dabbah
# Processing Record 12 of Set 9 | marlin
# Processing Record 13 of Set 9 | sogndal
# Processing Record 14 of Set 9 | miquelon
# Processing Record 15 of Set 9 | kofele
# Processing Record 16 of Set 9 | tomatlan
# Processing Record 17 of Set 9 | gizo
# Processing Record 18 of Set 9 | piriyapatna
# Processing Record 19 of Set 9 | khurba
# Processing Record 20 of Set 9 | saint-pierre
# Processing Record 21 of Set 9 | svetlyy
# Processing Record 22 of Set 9 | san juan
# Processing Record 23 of Set 9 | tokar
# Processing Record 24 of Set 9 | muisne
# Processing Record 25 of Set 9 | razampeta
# Processing Record 26 of Set 9 | port de pollenca
# Processing Record 27 of Set 9 | grand falls-windsor
# Processing Record 28 of Set 9 | new norfolk
# Processing Record 29 of Set 9 | garoua boulai
# Processing Record 30 of Set 9 | harnosand
# Processing Record 31 of Set 9 | kavieng
# Processing Record 32 of Set 9 | uzhur
# Processing Record 33 of Set 9 | santa rosalia
# Processing Record 34 of Set 9 | novoarkhanhel's'k
# Processing Record 35 of Set 9 | valparaiso
# Processing Record 36 of Set 9 | luanda
# Processing Record 37 of Set 9 | axim
# Processing Record 38 of Set 9 | sitka
# Processing Record 39 of Set 9 | novoselitskoye
# Processing Record 40 of Set 9 | gadzhiyevo
# Processing Record 41 of Set 9 | el daein
# City not found. Skipping...
# Processing Record 42 of Set 9 | siverskiy
# Processing Record 43 of Set 9 | cidreira
# Processing Record 44 of Set 9 | inirida
# Processing Record 45 of Set 9 | rodolfo sanchez taboada
# Processing Record 46 of Set 9 | alto araguaia
# Processing Record 47 of Set 9 | altamira
# Processing Record 48 of Set 9 | mersing
# Processing Record 49 of Set 9 | fang
# Processing Record 0 of Set 10 | uliastay
# Processing Record 1 of Set 10 | alaca
# Processing Record 2 of Set 10 | niquelandia
# Processing Record 3 of Set 10 | tefe
# Processing Record 4 of Set 10 | mtwara
# Processing Record 5 of Set 10 | kerikeri
# Processing Record 6 of Set 10 | yarmouth
# Processing Record 7 of Set 10 | xinyuan
# Processing Record 8 of Set 10 | nikolayevsk-on-amure
# Processing Record 9 of Set 10 | saratamata
# City not found. Skipping...
# Processing Record 10 of Set 10 | mount pearl
# Processing Record 11 of Set 10 | menongue
# Processing Record 12 of Set 10 | sebezh
# Processing Record 13 of Set 10 | sao gabriel da cachoeira
# Processing Record 14 of Set 10 | khovd
# Processing Record 15 of Set 10 | coahuayana de hidalgo
# Processing Record 16 of Set 10 | jos
# Processing Record 17 of Set 10 | ouesso
# Processing Record 18 of Set 10 | myshkin
# Processing Record 19 of Set 10 | barreiras
# Processing Record 20 of Set 10 | roma
# Processing Record 21 of Set 10 | laela
# Processing Record 22 of Set 10 | buedu
# Processing Record 23 of Set 10 | damongo
# City not found. Skipping...
# Processing Record 24 of Set 10 | tolanaro
# Processing Record 25 of Set 10 | ust'-barguzin
# Processing Record 26 of Set 10 | loukhi
# Processing Record 27 of Set 10 | swakopmund
# Processing Record 28 of Set 10 | nizhnesortymskiy
# Processing Record 29 of Set 10 | 'izbat al burj
# City not found. Skipping...
# Processing Record 30 of Set 10 | tsiombe
# Processing Record 31 of Set 10 | princeville
# Processing Record 32 of Set 10 | mishelevka
# Processing Record 33 of Set 10 | pierre
# Processing Record 34 of Set 10 | illizi
# Processing Record 35 of Set 10 | labrador city
# Processing Record 36 of Set 10 | pupiales
# Processing Record 37 of Set 10 | rundu
# Processing Record 38 of Set 10 | palikir - national government center
# Processing Record 39 of Set 10 | richards bay
# Processing Record 40 of Set 10 | san luis rio colorado
# Processing Record 41 of Set 10 | chirilagua
# Processing Record 42 of Set 10 | berdigestyakh
# Processing Record 43 of Set 10 | krasne
# Processing Record 44 of Set 10 | zheleznodorozhnyy
# Processing Record 45 of Set 10 | jebrail
# Processing Record 46 of Set 10 | bonthe
# Processing Record 47 of Set 10 | puttalam
# Processing Record 48 of Set 10 | luwuk
# Processing Record 49 of Set 10 | mullovka
# Processing Record 0 of Set 11 | bouar
# Processing Record 1 of Set 11 | brady
# Processing Record 2 of Set 11 | ringkobing
# Processing Record 3 of Set 11 | waingapu
# Processing Record 4 of Set 11 | shira
# Processing Record 5 of Set 11 | valle de la pascua
# Processing Record 6 of Set 11 | nabire
# Processing Record 7 of Set 11 | sechura
# Processing Record 8 of Set 11 | toga village
# City not found. Skipping...
# Processing Record 9 of Set 11 | dunay
# Processing Record 10 of Set 11 | kshenskiy
# Processing Record 11 of Set 11 | mil'kovo
# Processing Record 12 of Set 11 | itabera
# Processing Record 13 of Set 11 | aripuana
# Processing Record 14 of Set 11 | hauterive
# Processing Record 15 of Set 11 | red deer
# Processing Record 16 of Set 11 | smithers
# Processing Record 17 of Set 11 | cargados carajos
# City not found. Skipping...
# Processing Record 18 of Set 11 | sorong
# Processing Record 19 of Set 11 | isla mujeres
# Processing Record 20 of Set 11 | crookston
# Processing Record 21 of Set 11 | sungjibaegam
# Processing Record 22 of Set 11 | mahanoro
# Processing Record 23 of Set 11 | 'ain el turk
# Processing Record 24 of Set 11 | at taj
# Processing Record 25 of Set 11 | joshimath
# Processing Record 26 of Set 11 | dunedin
# Processing Record 27 of Set 11 | razdol'noye
# Processing Record 28 of Set 11 | namsos
# Processing Record 29 of Set 11 | brookings
# Processing Record 30 of Set 11 | santa elena de uairen
# Processing Record 31 of Set 11 | podporozh'ye
# Processing Record 32 of Set 11 | ciudad del carmen
# Processing Record 33 of Set 11 | chittarkonda
# Processing Record 34 of Set 11 | kazalinsk
# City not found. Skipping...
# Processing Record 35 of Set 11 | port-cartier
# Processing Record 36 of Set 11 | igrim
# Processing Record 37 of Set 11 | ardestan
# Processing Record 38 of Set 11 | mikomeseng
# Processing Record 39 of Set 11 | kongolo
# Processing Record 40 of Set 11 | vohibinany
# Processing Record 41 of Set 11 | hammerfest
# Processing Record 42 of Set 11 | tofol
# Processing Record 43 of Set 11 | pont rouge
# Processing Record 44 of Set 11 | ornskoldsvik
# Processing Record 45 of Set 11 | howard springs
# Processing Record 46 of Set 11 | olinda
# Processing Record 47 of Set 11 | cynthiana
# Processing Record 48 of Set 11 | amahai
# Processing Record 49 of Set 11 | puerto armuelles
# Processing Record 0 of Set 12 | preobrazheniye
# Processing Record 1 of Set 12 | kulhudhuffushi
# Processing Record 2 of Set 12 | forster
# Processing Record 3 of Set 12 | tshabong
# Processing Record 4 of Set 12 | jaisalmer
# Processing Record 5 of Set 12 | ar ruways
# Processing Record 6 of Set 12 | korla
# Processing Record 7 of Set 12 | lagodekhi
# Processing Record 8 of Set 12 | shreveport
# Processing Record 9 of Set 12 | tres isletas
# Processing Record 10 of Set 12 | regina
# Processing Record 11 of Set 12 | nicoya
# Processing Record 12 of Set 12 | zhangjiakou
# Processing Record 13 of Set 12 | rumoi
# Processing Record 14 of Set 12 | spearfish
# Processing Record 15 of Set 12 | tobi village
# City not found. Skipping...
# Processing Record 16 of Set 12 | long beach
# Processing Record 17 of Set 12 | belvedere marittimo
# Processing Record 18 of Set 12 | aromashevo
# Processing Record 19 of Set 12 | atherton
# Processing Record 20 of Set 12 | sereflikochisar
# Processing Record 21 of Set 12 | alvorada
# Processing Record 22 of Set 12 | konarka
# Processing Record 23 of Set 12 | kailua-kona
# Processing Record 24 of Set 12 | anton lizardo
# Processing Record 25 of Set 12 | mariental
# Processing Record 26 of Set 12 | develi
# Processing Record 27 of Set 12 | ilula
# Processing Record 28 of Set 12 | iskitim
# Processing Record 29 of Set 12 | machico
# Processing Record 30 of Set 12 | gamba
# Processing Record 31 of Set 12 | dryden
# Processing Record 32 of Set 12 | titao
# Processing Record 33 of Set 12 | posto fiscal rolim de moura
# Processing Record 34 of Set 12 | east london
# Processing Record 35 of Set 12 | loen
# Processing Record 36 of Set 12 | pyhajarvi
# Processing Record 37 of Set 12 | portland
# Processing Record 38 of Set 12 | floro
# Processing Record 39 of Set 12 | fort william
# Processing Record 40 of Set 12 | dolinsk
# Processing Record 41 of Set 12 | altinyayla
# Processing Record 42 of Set 12 | upington
# Processing Record 43 of Set 12 | tambacounda
# Processing Record 44 of Set 12 | kisaran
# Processing Record 45 of Set 12 | sao felix do xingu
# Processing Record 46 of Set 12 | sunagawa
# Processing Record 47 of Set 12 | fuerte olimpo
# Processing Record 48 of Set 12 | guigang
# Processing Record 49 of Set 12 | ulladulla
# Processing Record 0 of Set 13 | lindi
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame.from_dict(city_data)

# Show Record Count
city_data_df.count()
# Out:
# City          580
# Lat           580
# Lng           580
# Max Temp      580
# Humidity      580
# Cloudiness    580
# Wind Speed    580
# Country       580
# Date          580
# dtype: int64

# %%
# Display sample data
city_data_df.head()
# Out:
#                 City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0          gaigeturi  33.4644  126.3183     29.20        72          43
# 1            margate  51.3813    1.3862     15.94        88          92
# 2     puerto natales -51.7236  -72.4875      0.36        93          75
# 3          grytviken -54.2811  -36.5092     -3.67        53           0
# 4  port-aux-francais -49.3500   70.2167      1.23        68          56
#
#    Wind Speed Country        Date
# 0        0.80      KR  1723853343
# 1        3.77      GB  1723853343
# 2        2.18      CL  1723853343
# 3        1.10      GS  1723853344
# 4       16.34      TF  1723853344

# %%
# Export the City_Data into a csv
city_data_df.to_csv("output_data/cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("output_data/cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#                       City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0                gaigeturi  33.4644  126.3183     29.20        72          43
# 1                  margate  51.3813    1.3862     15.94        88          92
# 2           puerto natales -51.7236  -72.4875      0.36        93          75
# 3                grytviken -54.2811  -36.5092     -3.67        53           0
# 4        port-aux-francais -49.3500   70.2167      1.23        68          56
#
#          Wind Speed Country        Date
# City_ID
# 0              0.80      KR  1723853343
# 1              3.77      GB  1723853343
# 2              2.18      CL  1723853343
# 3              1.10      GS  1723853344
# 4             16.34      TF  1723853344

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature
plt.scatter(city_data_df["Lat"], city_data_df["Max Temp"], alpha=.8, edgecolors="k")

#Format date
date = datetime.now()
date = date.strftime("%m-%d-%Y")

# Incorporate the other graph properties
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (C)")
plt.title(f"City Latitude vs. Temperature ({date})")
plt.grid(True) 
plt.tight_layout()

# Save the figure
plt.savefig("output_data/Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
plt.scatter(city_data_df["Lat"], city_data_df["Humidity"], alpha=.8, edgecolors="k")

#Format date from UTC to m/d/y
date = datetime.now()
date = date.strftime("%m-%d-%Y")

# Incorporate the other graph properties
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.title(f"City Latitude vs. Humidity (%) ({date})")
plt.grid(True) 
plt.tight_layout()

# Save the figure
plt.savefig("output_data/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
plt.scatter(city_data_df["Lat"], city_data_df["Cloudiness"], alpha=.8, edgecolors="k")

#Format date from UTC to m/d/y
date = datetime.now()
date = date.strftime("%m-%d-%Y")

# Incorporate the other graph properties
plt.xlabel("Latitude")
plt.ylabel("Cloudiness")
plt.title(f"City Latitude vs. Cloudiness ({date})")
plt.grid(True) 
plt.tight_layout()

# Save the figure
plt.savefig("output_data/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
plt.scatter(city_data_df["Lat"], city_data_df["Wind Speed"], alpha=.8, edgecolors="k")

#Format date from UTC to m/d/y
date = datetime.now()
date = date.strftime("%m-%d-%Y")

# Incorporate the other graph properties
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (m/s)")
plt.title(f"City Latitude vs. Wind Speed ({date})")
plt.grid(True) 
plt.tight_layout()

# Save the figure
plt.savefig("output_data/Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
northern_hemi_df = city_data_df.loc[pd.to_numeric(city_data_df["Lat"]) > 0, :]

# Display sample data
northern_hemi_df.head()
# Out:
#                            City      Lat       Lng  Max Temp  Humidity  \
# City_ID
# 0                     gaigeturi  33.4644  126.3183     29.20        72
# 1                       margate  51.3813    1.3862     15.94        88
# 6                        harnai  30.1005   67.9374     26.14        71
# 11                       jining  35.4050  116.5814     26.96        86
# 12       hawaiian paradise park  19.5933 -154.9731     27.63        80
#
#          Cloudiness  Wind Speed Country        Date
# City_ID
# 0                43        0.80      KR  1723853343
# 1                92        3.77      GB  1723853343
# 6                98        0.35      PK  1723853344
# 11               38        1.01      CN  1723853344
# 12              100        5.14      US  1723853345

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
southern_hemi_df = city_data_df.loc[pd.to_numeric(city_data_df["Lat"]) < 0, :]

# Display sample data
southern_hemi_df.head()
# Out:
#                       City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 2           puerto natales -51.7236  -72.4875      0.36        93          75
# 3                grytviken -54.2811  -36.5092     -3.67        53           0
# 4        port-aux-francais -49.3500   70.2167      1.23        68          56
# 5            port mathurin -19.6833   63.4167     22.92        72          34
# 7                 waitangi -43.9535 -176.5597      9.90        81          80
#
#          Wind Speed Country        Date
# City_ID
# 2              2.18      CL  1723853343
# 3              1.10      GS  1723853344
# 4             16.34      TF  1723853344
# 5              8.96      MU  1723853344
# 7              2.24      NZ  1723853344

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Max Temp"]
slope = linregress(x_values, y_values)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

#Plot values
plt.scatter(x_values, y_values)
plt.plot(x_values, regress_values, "-r")
plt.annotate(line_eq,(0,-20),fontsize=15,color="red")
plt.xlabel("Latitude")
plt.ylabel("Max Temp")
print(f'The r-value is {rvalue}')
print("-----------------------------------")
print("Observations about linear relationship:")
print("The regression displays a negative relationship between temperature and latitude")
print("In the northern hemisphere, as the latitude increases the distance from the equator increases")
print("As you move away from the equator, the max temperature decreases.")
# Out:
# The r-value is -0.6835036249430744
# -----------------------------------
# Observations about linear relationship:
# The regression displays a negative relationship between temperature and latitude
# In the northern hemisphere, as the latitude increases the distance from the equator increases
# As you move away from the equator, the max temperature decreases.

# %%
# Linear regression on Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Max Temp"]
slope = linregress(x_values, y_values)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

#Plot values
plt.scatter(x_values, y_values)
plt.plot(x_values, regress_values, "-r")
plt.annotate(line_eq,(-25,15),fontsize=15,color="red")
plt.xlabel("Latitude")
plt.ylabel("Max Temp")
print(f'The r-value is {rvalue}')
print("-----------------------------------")
print("Observations about linear relationship:")
print("The regression displays a sligtly positive relationship between temperature and latitude.")
print("In the southern hemisphere, as the latitude increases the distance from the equator decreases")
print("As you move closer to the equator, the max temperature generally increases.")
# Out:
# The r-value is 0.8148531846961148
# -----------------------------------
# Observations about linear relationship:
# The regression displays a sligtly positive relationship between temperature and latitude.
# In the southern hemisphere, as the latitude increases the distance from the equator decreases
# As you move closer to the equator, the max temperature generally increases.

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Humidity"]
slope = linregress(x_values, y_values)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

#Plot values
plt.scatter(x_values, y_values)
plt.plot(x_values, regress_values, "-r")
plt.annotate(line_eq,(40,20),fontsize=15,color="red")
plt.xlabel("Latitude")
plt.ylabel("Humidity")
print(f'The r-value is {rvalue}')
print("-----------------------------------")
print("Observations about linear relationship:")
print("The relationship is slightly negative, though there doesn't appear to be a strong correlation between humidity and latitude.")
# Out:
# The r-value is -0.04266146048987498
# -----------------------------------
# Observations about linear relationship:
# The relationship is slightly negative, though there doesn't appear to be a strong correlation between humidity and latitude.

# %%
# Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Humidity"]
slope = linregress(x_values, y_values)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

#Plot values
plt.scatter(x_values, y_values)
plt.plot(x_values, regress_values, "-r")
plt.annotate(line_eq,(-25,25),fontsize=15,color="red")
plt.xlabel("Latitude")
plt.ylabel("Humidity")
print(f'The r-value is {rvalue}')
print("-----------------------------------")
print("Observations about linear relationship:")
print("The relationship is slightly positive.")
print("Humidity increases as cities get closer to the equator.")
# Out:
# The r-value is -0.063067965187454
# -----------------------------------
# Observations about linear relationship:
# The relationship is slightly positive.
# Humidity increases as cities get closer to the equator.

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Cloudiness"]
slope = linregress(x_values, y_values)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

#Plot values
plt.scatter(x_values, y_values)
plt.plot(x_values, regress_values, "-r")
plt.annotate(line_eq,(40,20),fontsize=15,color="red")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness")
print(f'The r-value is {rvalue}')
print("-----------------------------------")
print("Observations about linear relationship:")
print("There seem to be a negative correlation between latitude and cloudiness.")
# Out:
# The r-value is -0.16424734473514838
# -----------------------------------
# Observations about linear relationship:
# There seem to be a negative correlation between latitude and cloudiness.

# %%
# Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Cloudiness"]
slope = linregress(x_values, y_values)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

#Plot values
plt.scatter(x_values, y_values)
plt.plot(x_values, regress_values, "-r")
plt.annotate(line_eq,(-25,15),fontsize=15,color="red")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness")
print(f'The r-value is {rvalue}')
print("-----------------------------------")
print("Observations about linear relationship:")
print("There seem to be a slight negative correlation between latitude and cloudiness.")
# Out:
# The r-value is -0.06840945144177837
# -----------------------------------
# Observations about linear relationship:
# There seem to be a slight negative correlation between latitude and cloudiness.

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Wind Speed"]
slope = linregress(x_values, y_values)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

#Plot values
plt.scatter(x_values, y_values)
plt.plot(x_values, regress_values, "-r")
plt.annotate(line_eq,(15,10),fontsize=15,color="red")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed")
print(f'The r-value is {rvalue}')
print("-----------------------------------")
print("Observations about linear relationship:")
print("There does not appear to be a correlation between latitude and wind speed.")
# Out:
# The r-value is -0.09163974393376412
# -----------------------------------
# Observations about linear relationship:
# There does not appear to be a correlation between latitude and wind speed.

# %%
# Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Wind Speed"]
slope = linregress(x_values, y_values)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

#Plot values
plt.scatter(x_values, y_values)
plt.plot(x_values, regress_values, "-r")
plt.annotate(line_eq,(-25,10),fontsize=15,color="red")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed")
print(f'The r-value is {rvalue}')
# Out:
# The r-value is -0.1134718479797071

# %% [markdown]
# **Discussion about the linear relationship: the linear gragh is showing that that there is no obvious correlation between the latitude and the wind speed
